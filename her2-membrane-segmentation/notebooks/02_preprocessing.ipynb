# %% [markdown]
# # 02. Preprocessing
#
# This notebook runs the data preparation script to unify the data formats and visualize the training, validation, and test splits.

# %%
# !python ../src/data/prepare.py
