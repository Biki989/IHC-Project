# %% [markdown]
# # 01. Data Exploration
#
# In this notebook, we explore the raw HER2 WSI patches and masks across the different annotators.

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
import tifffile
