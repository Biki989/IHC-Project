# %% [markdown]
# # 03. Training Demo (U-Net)
#
# This notebook demonstrates how to launch the U-Net training pipeline and monitor it via Weights & Biases.

# %%
# !python ../scripts/train_unet.py --config ../configs/unet.yaml
